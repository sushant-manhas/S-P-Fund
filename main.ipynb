# %%
import numpy as np
import pandas as pd

# %%
final_dataframe = pd.read_csv('/content/final_dataframe.csv')
final_dataframe = final_dataframe.drop('Number of Stiocks to Buy', axis=1)
final_dataframe['Number of Stocks to Buy'] = 0
final_dataframe['Number of Stocks to Buy'] = final_dataframe['Number of Stocks to Buy'].map('{:.8f}'.format)
final_dataframe.head()
# Out:
#   Ticker  Stock Price  Market Capitalization Number of Stocks to Buy
# 0      A       126.86           3.747138e+10              0.00000000
# 1    AAL        15.65           1.022512e+10              0.00000000
# 2    AAP        72.28           4.296602e+09              0.00000000
# 3   AAPL       177.79           2.779610e+12              0.00000000
# 4   ABBV       152.18           2.686048e+11              0.00000000

# %%
protfolio_value = input('Enter your portfolio amount: ')

try:
  val = float(protfolio_value)
except ValueError:
  print('That is not a Number! \n Please try again:')
  protfolio_value = input('Enter your portfolio amount: ')
  val = float(protfolio_value)
# Out:
# Enter your portfolio amount: 100000

# %%
position_size = val / len(final_dataframe.index)

for index, row in final_dataframe.iterrows():
    ticker = row['Ticker']
    stock_price = float(row['Stock Price'])
    number_of_shares = position_size / stock_price
    final_dataframe.at[index, 'Number of Stocks to Buy'] = math.floor(number_of_shares)

print(final_dataframe)
# Out:
#     Ticker  Stock Price  Market Capitalization Number of Stocks to Buy
# 0        A       126.86           3.747138e+10                       3
# 1      AAL        15.65           1.022512e+10                      31
# 2      AAP        72.28           4.296602e+09                       6
# 3     AAPL       177.79           2.779610e+12                       2
# 4     ABBV       152.18           2.686048e+11                       3
# ..     ...          ...                    ...                     ...
# 195   FTNT        59.68           4.686891e+10                       8
# 196    FTV        79.41           2.795426e+10                       6
# 197     GD       226.99           6.197793e+10                       2
# 198     GE       114.60           1.247281e+11                       4
# 199   GILD        80.00           9.968115e+10                       6
#
# [200 rows x 4 columns]
