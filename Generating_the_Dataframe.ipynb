# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import sys
sys.path.append('/content')  # Add the content folder to the Python path
import warnings
warnings.filterwarnings("ignore")

# %%
stocks = pd.read_csv('/content/sp_500_stocks.csv')
stocks.head()
# Out:
#   Ticker
# 0      A
# 1    AAL
# 2    AAP
# 3   AAPL
# 4   ABBV

# %%
from secret import IEX_CLOUD_API_TOKEN

# %%
symbol = 'AAPL'
api_url = f'https://api.iex.cloud/v1/data/core/quote/{symbol}?token={IEX_CLOUD_API_TOKEN}'
print(IEX_CLOUD_API_TOKEN)
data = requests.get(api_url).json()
print(data)
print(type(data))
dictionary_data = data[0]
print(type(dictionary_data))
# Out:
# pk_0bfb3305912a49ffa0f5451a5ecc1e66
# ...

# %%
price = dictionary_data['latestPrice']
market_cap = dictionary_data['marketCap']

# %%
columns_dataframe = ['Ticker', 'Stock Price', 'Market Capitalization', 'Number of Stiocks to Buy']
final_dataframe = pd.DataFrame(columns = columns_dataframe)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Stock Price, Market Capitalization, Number of Stiocks to Buy]
# Index: []

# %%
final_dataframe.append(
    pd.Series(
        [
            symbol,
            price,
            market_cap,
            'N/A'
        ],
        index = columns_dataframe,
    ),
    ignore_index = True
)
# Out:
# <ipython-input-91-fe913abca27b>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe.append(
#   Ticker  Stock Price Market Capitalization Number of Stiocks to Buy
# 0   AAPL       177.79         2779610107280                      N/A

# %%
final_dataframe = pd.DataFrame(columns = columns_dataframe)
for stock in stocks['Ticker'][:25]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][25:50]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][50:75]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][75:100]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][100:125]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][125:150]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][150:175]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
for stock in stocks['Ticker'][175:200]:
  api_url = f'https://api.iex.cloud/v1/data/core/quote/{stock}?token={IEX_CLOUD_API_TOKEN}'
  data = requests.get(api_url).json()
  dictionary_data = data[0]
  final_dataframe = final_dataframe.append(
      pd.Series(
          [
              stock,
              dictionary_data['latestPrice'],
              dictionary_data['marketCap'],
              'N/A'
          ],
          index = columns_dataframe,
      ),
      ignore_index= True
  )

# %%
print(final_dataframe)
csv_file_path = '/content/final_dataframe.csv'

final_dataframe.to_csv(csv_file_path, index=False)  # Set index=False to avoid saving the index column
# Out:
#     Ticker  Stock Price Market Capitalization Number of Stiocks to Buy
# 0        A       126.86           37471376271                      N/A
# 1      AAL        15.65           10225122123                      N/A
# 2      AAP        72.28            4296601623                      N/A
# 3     AAPL       177.79         2779610107280                      N/A
# 4     ABBV       152.18          268604803762                      N/A
# ..     ...          ...                   ...                      ...
# 195   FTNT        59.68           46868908400                      N/A
# 196    FTV        79.41           27954255619                      N/A
# 197     GD       226.99           61977933191                      N/A
# 198     GE       114.60          124728140918                      N/A
# 199   GILD        80.00           99681148240                      N/A
#
# [200 rows x 4 columns]

# %%
position_size = val/len(final_dataframe.index)
for ticker in final_dataframe['Ticker']:
  number_of_shares = position_size/final_dataframe['Stock Price']
  final_dataframe.loc[f'{ticker}', 'Number of Stiocks to Buy'] = math.floor(number_of_shares)
print(number_of_shares)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9be91791eabd> in <cell line: 1>()
# ----> 1 position_size = val/len(final_dataframe.index)
#       2 for ticker in final_dataframe['Ticker']:
#       3   number_of_shares = position_size/final_dataframe['Stock Price']
#       4   final_dataframe.loc[f'{ticker}', 'Number of Stiocks to Buy'] = math.floor(number_of_shares)
#       5 print(number_of_shares)
#
# NameError: name 'val' is not defined
